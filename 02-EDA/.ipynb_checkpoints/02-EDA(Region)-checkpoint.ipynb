# %% [markdown]
# ## 데이터 시각화(2)
# ### 지역 관점으로 EDA
# - 지역별로는 어떻게 봐야할까?
#     - 좌표는 달려있음
#         - Reverse Geocoding : 위도/경도 => 주소로 변환
#         - API를 날려야할까?
#         - BigQuery GIS엔 shp 파일을 Join해서 찾아내는 기능이 있음

# %% [markdown]
# - Shp 파일
#     - `bigquery-public-data.geo_us_boundaries.zip_codes`에 저장됨
#     - pickup_longitude, pickup_latitude가 zip_code_geom에 속하면 그 지역
# - BigQuery GIS
#     - [공식 문서](https://cloud.google.com/bigquery/docs/gis-intro?hl=ko)
#     - [Geography functions](https://cloud.google.com/bigquery/docs/reference/standard-sql/geography_functions)

# %%
import plotly.plotly as py
import cufflinks as cf
import pandas as pd
import numpy as np
import seaborn as sns
print(cf.__version__)
cf.go_offline()
# %config InlineBackend.figure_format = 'retina'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 0.16
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# %%time

query = """
WITH base_data AS (
  SELECT 
    *
  FROM `bigquery-public-data.new_york_taxi_trips.tlc_yellow_trips_2015`
  WHERE EXTRACT(MONTH from pickup_datetime) = 1
), temp AS (
  SELECT nyc_taxi.*, gis.* 
  FROM (
    SELECT *
    FROM base_data
    WHERE pickup_latitude  <= 90 and pickup_latitude >= -90
    ) as nyc_taxi
  JOIN (
    SELECT zip_code, state_code, state_name, city, county, zip_code_geom
    FROM `bigquery-public-data.geo_us_boundaries.zip_codes`
    WHERE state_code='NY'
    ) as gis 
  ON st_contains(zip_code_geom, st_geogpoint(pickup_longitude, pickup_latitude))
)

SELECT 
  zip_code, 
  city,
  ST_ASTEXT(zip_code_geom) as zip_code_geom,
  DATETIME_TRUNC(pickup_datetime_ny, hour) as pickup_hour,
  count(*) as cnt
FROM temp
GROUP BY zip_code, city, zip_code_geom, pickup_hour
ORDER BY pickup_hour
"""

df = pd.read_gbq(query=query, dialect='standard', project_id='geultto')
# Out:
# CPU times: user 8.6 s, sys: 1.22 s, total: 9.82 s
# Wall time: 2min 37s

# %%
df.head()
# Out:
#   zip_code           city                                      zip_code_geom  \
# 0    10028  New York city  POLYGON((-73.96316 40.777772, -73.96323 40.777...
# 1    10039  New York city  POLYGON((-73.942924 40.82326, -73.943506 40.82...
# 2    10069  New York city  POLYGON((-73.995969 40.774012, -73.996142 40.7...
# 3    10044  New York city  POLYGON((-73.961588 40.749823, -73.96156 40.74...
# 4    10030  New York city  POLYGON((-73.948356 40.816374, -73.948677 40.8...
#
#   pickup_hour  cnt
# 0  2015-01-01  120
# 1  2015-01-01    7
# 2  2015-01-01    8
# 3  2015-01-01    1
# 4  2015-01-01   26

# %% [markdown]
# ### Trip이 많은 zip_code는?

# %%
zip_code_agg_df = df.groupby(['zip_code', 'zip_code_geom'])[['cnt']].sum().reset_index()

# %%
zip_code_agg_df['percent'] = (zip_code_agg_df[['cnt']]/df[['cnt']].sum()).round(3).rename(columns={'cnt':'percent'}).reset_index()['percent']

# %%
zip_code_agg_df.head(2)
# Out:
#   zip_code                                      zip_code_geom     cnt  percent
# 0    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...  627145    0.051
# 1    10002  POLYGON((-73.997504 40.714069, -73.9973 40.713...  237199    0.019

# %%
filter_agg_df = zip_code_agg_df[zip_code_agg_df['percent'] > 0.000]

# %%
filter_agg_df['cnt'].sum()
# Out:
# 12175111

# %%
filter_zip_code = filter_agg_df['zip_code'].to_list()

# %%
zip_code_agg_df['cnt'].sum()
# Out:
# 12294985

# %%
filter_agg_df.to_csv("zip_code_ratio.csv", index=False)

# %% [markdown]
# ### Kepler.gl에서 시각화
# - [Kepler.gl](https://kepler.gl/demo)
# - <img src="https://www.dropbox.com/s/v18lb654qhrqx9l/Screenshot%202019-10-12%2016.01.45.png?raw=1">

# %% [markdown]
# - 좌측의 Fill Color 옆에 있는 점 3개 클릭
#     - Select a field에 percent 클릭
# <img src="https://www.dropbox.com/s/g0iautf1tb55y89/Screenshot%202019-10-12%2016.03.24.png?raw=1">

# %%
zip_df = df[['zip_code', 'zip_code_geom', 'pickup_hour', 'cnt']]

# %%
zip_df['date'] = zip_df['pickup_hour'].dt.date

# %%
zip_df[zip_df['zip_code'] == '10001'].set_index('pickup_hour')['cnt'].plot();

# %%
sns.boxplot(x="day", y="total_bill", data=zip_df)

# %% [markdown]
# ### 하루 단위 zip_code별 Trip Box Plot

# %%
filter_zip_df = zip_df[zip_df['zip_code'].isin(filter_zip_code)]

# %%
filter_zip_daily_df = filter_zip_df.groupby(['zip_code','date'])[['cnt']].sum().reset_index()

# %%
# cufflinks => 드래그로 가능
filter_zip_daily_df.pivot_table('cnt', index='date', columns='zip_code').iplot(kind='box', x='zip_code')
# Out:
# <div>
#
#
#             <div id="c967f68a-e6e8-44bd-b30d-624e123c535c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c967f68a-e6e8-44bd-b30d-624e123c535c")) {
#                     Plotly.newPlot(
#                         'c967f68a-e6e8-44bd-b30d-624e123c535c',
#                         [{"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(255, 153, 51, 1.0)"}, "name": "10001", "orientation": "v", "type": "box", "uid": "2143c7cc-58da-4a84-8130-c12bb08ec5be", "y": [12929, 18881, 20707, 14377, 17302, 18783, 21187, 23022, 24336, 25786, 17193, 21875, 24002, 21767, 21867, 25247, 23062, 18745, 17578, 20639, 21487, 22741, 25151, 24377, 16918, 9684, 5655, 18896, 21640, 26274, 25037]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(55, 128, 191, 1.0)"}, "name": "10002", "orientation": "v", "type": "box", "uid": "8ec372e1-4fbd-4e66-8f79-a7b893a4cc05", "y": [5981, 9545, 10754, 4383, 3825, 4327, 5058, 6101, 12118, 15345, 5771, 4158, 5581, 5609, 6867, 12918, 14572, 7365, 4795, 5091, 5278, 6696, 10830, 15129, 5798, 1700, 2195, 4620, 6272, 13396, 15121]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(50, 171, 96, 1.0)"}, "name": "10003", "orientation": "v", "type": "box", "uid": "7d81e465-6439-4dab-a52d-4276fb086382", "y": [16533, 22770, 26172, 14201, 16414, 17955, 21157, 23218, 29304, 36235, 18105, 18238, 21679, 21723, 23389, 31761, 34579, 23410, 15832, 19760, 20980, 23829, 30169, 32459, 17586, 9263, 8449, 19095, 23011, 32678, 37863]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(128, 0, 128, 1.0)"}, "name": "10004", "orientation": "v", "type": "box", "uid": "33c292cb-27d8-424d-a677-3b70ba5f762c", "y": [1573, 2077, 1598, 1021, 1940, 1822, 2287, 2485, 2440, 1774, 1176, 1976, 2533, 2551, 2767, 2586, 1770, 1123, 1231, 2156, 2349, 2599, 2578, 1591, 1321, 850, 501, 1996, 2366, 2500, 1819]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(219, 64, 82, 1.0)"}, "name": "10005", "orientation": "v", "type": "box", "uid": "53ae1507-207c-45eb-b4c2-f9043ad8aa19", "y": [949, 1329, 1279, 902, 1511, 1730, 1951, 2077, 2162, 1704, 1179, 1833, 2038, 2113, 2126, 2197, 1623, 1115, 1225, 1952, 2159, 2201, 2295, 1743, 1185, 885, 553, 1829, 2094, 2265, 1913]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(0, 128, 128, 1.0)"}, "name": "10006", "orientation": "v", "type": "box", "uid": "5248ab5d-eb6b-492e-8c67-15fc68ce1b3f", "y": [1342, 1432, 1580, 932, 971, 950, 1154, 1234, 1214, 1405, 942, 1174, 1274, 1137, 1221, 1315, 1601, 1002, 975, 1088, 1111, 1256, 1324, 1297, 982, 441, 397, 941, 1128, 1250, 1393]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(255, 255, 51, 1.0)"}, "name": "10007", "orientation": "v", "type": "box", "uid": "6e446319-a248-49e1-899f-3bfec2df8b7b", "y": [2058, 2621, 2314, 1660, 2465, 2520, 3094, 3357, 3402, 3548, 2182, 2819, 3338, 3228, 3599, 3572, 2929, 2052, 1916, 2881, 3204, 3476, 3648, 2860, 2124, 1433, 932, 2783, 3398, 3926, 3298]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(128, 128, 0, 1.0)"}, "name": "10009", "orientation": "v", "type": "box", "uid": "47eb76fb-51bc-42b0-94c8-9ce47bc8a9a9", "y": [6814, 9722, 10636, 5525, 5253, 5477, 6499, 6897, 11139, 14663, 6617, 5024, 6128, 6393, 7086, 11814, 14697, 8843, 6016, 5769, 6013, 7308, 11126, 14345, 6937, 3147, 2955, 5658, 6890, 12725, 15720]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(251, 128, 114, 1.0)"}, "name": "10010", "orientation": "v", "type": "box", "uid": "5941ee5f-2f9f-408d-a0e1-25804494776e", "y": [7132, 10710, 11388, 7104, 10540, 11730, 13403, 14626, 15532, 16762, 9616, 12594, 13870, 13923, 14839, 16276, 14777, 10445, 9196, 13077, 13681, 14914, 16230, 14687, 8902, 6502, 4529, 12491, 14296, 17126, 16454]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(128, 177, 211, 1.0)"}, "name": "10011", "orientation": "v", "type": "box", "uid": "f769839e-d6df-4f17-b224-6598739ebe84", "y": [11905, 18789, 20330, 13079, 16169, 17869, 20310, 22888, 25475, 30296, 17576, 18200, 21978, 21675, 23637, 27900, 29807, 19837, 16015, 19392, 21432, 24006, 26822, 27743, 17243, 9451, 7319, 18863, 22654, 28513, 32627]}, {"box ...

# %%
# seaborn
plt.figure(figsize=(16, 6));
sns.boxplot(x='zip_code', y='cnt', data=filter_zip_daily_df);

# %%
filter_zip_df[filter_zip_df['zip_code'] == '10001']
# Out:
#       zip_code                                      zip_code_geom  \
# 34       10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 233      10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 412      10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 475      10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 665      10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 810      10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 921      10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 983      10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 1094     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 1271     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 1347     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 1551     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 1630     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 1768     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 1879     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 2031     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 2137     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 2198     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 2371     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 2476     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 2619     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 2704     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 2816     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 2947     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 3050     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 3170     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 3258     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 3293     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 3471     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 3603     10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# ...        ...                                                ...
# 83220    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 83365    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 83432    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 83668    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 83739    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 83879    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 83939    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 84115    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 84237    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 84365    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 84499    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 84562    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 84741    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 84821    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 84904    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 85083    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 85218    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 85236    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 85437    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 85530    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 85653    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 85808    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 85836    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 85966    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 86185    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 86281    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 86357    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 86598    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 86690    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
# 86874    10001  POLYGON((-74.00828 40.750272, -74.008255 40.75...
#
#               pickup_hour   cnt        date
# 34    2015-01-01 00:00:00   472  2015-01-01
# 233   2015-01-01 01:00:00   353  2015-01-01
# 412   2015-01-01 02:00:00   257  2015-01-01
# 475   2015-01-01 03:00:00   196  2015-01-01
# 665   2015-01-01 04:00:00   270  2015-01-01
# 810   2015-01-01 05:00:00   396  2015-01-01
# 921   2015-01-01 06:00:00   571  2015-01-01
# 983   2015-01-01 07:00:00   785  2015-01-01
# 1094  2015-01-01 08:00:00   878  2015-01-01
# 1271  2015-01-01 09:00:00   796  2015-01-01
# 1347  2015-01-01 10:00:00   853  2015-01-01
# 1551  2015-01-01 11:00:00   781  2015-01-01
# 1630  2015-01-01 12:00:00   790  2015-01-01
# 1768  2015-01-01 13:00:00   968  2015-01-01
# 1879  2015-01-01 14:00:00   849  2015-01-01
# 2031  2015-01-01 15:00:00   756  2015-01-01
# 2137  2015-01-01 16:00:00   673  2015-01-01
# 2198  2015-01-01 17:00:00   586  2015-01-01
# 2371  2015-01-01 18:00:00   438  2015-01-01
# 2476  2015-01-01 19:00:00   447  2015-01-01
# 2619  2015-01-01 20:00:00   378  2015-01-01
# 2704  2015-01-01 21:00:00   199  2015-01-01
# 2816  2015-01-01 22:00:00   123  2015-01-01
# 2947  2015-01-01 23:00:00   114  2015-01-01
# 3050  2015-01-02 00:00:00   150  2015-01-02
# 3170  2015-01-02 01:00:00   270  2015-01-02
# 3258  2015-01-02 02:00:00   344  2015-01-02
# 3293  2015-01-02 03:00:00   441  2015-01-02
# 3471  2015-01-02 04:00:00   588  2015-01-02
# 3603  2015-01-02 05:00:00   732  2015-01-02
# ...                   ...   ...         ...
# 83220 2015-01-30 18:00:00  1605  2015-01-30
# 83365 2015-01-30 19:00:00  1364  2015-01-30
# 83432 2015-01-30 20:00:00  1155  2015-01-30
# 83668 2015-01-30 21:00:00   940  2015-01-30
# 83739 2015-01-30 22:00:00   702  2015-01-30
# 83879 2015-01-30 23:00:00   525  2015-01-30
# 83939 2015-01-31 00:00:00   298  2015-01-31
# 84115 2015-01-31 01:00:00   309  2015-01-31
# 84237 2015-01-31 02:00:00   362  2015-01-31
# 84365 2015-01-31 03:00:00   497  2015-01-31
# 84499 2015-01-31 04:00:00   813  2015-01-31
# 84562 2015-01-31 05:00:00   993  2015-01-31
# 84741 2015-01-31 06:00:00  1182  2015-01-31
# 84821 2015-01-31 07:00:00  1299  2015-01-31
# 84904 2015-01-31 08:00:00  1371  2015-01-31
# 85083 2015-01-31 09:00:00  1229  2015-01-31
# 85218 2015-01-31 10:00:00  1261  2015-01-31
# 85236 2015-01-31 11:00:00  1131  2015-01-31
# 85437 2015-01-31 12:00:00  1128  2015-01-31
# 85530 2015-01-31 13:00:00  1468  2015-01-31
# 85653 2015-01-31 14:00:00  1534  2015-01-31
# 85808 2015-01-31 15:00:00  1219  2015-01-31
# 85836 2015-01-31 16:00:00  1574  2015-01-31
# 85966 2015-01-31 17:00:00  1385  2015-01-31
# 86185 2015-01-31 18:00:00  1300  2015-01-31
# 86281 2015-01-31 19:00:00  1188  2015-01-31
# 86357 2015-01-31 20:00:00  1085  2015-01-31
# 86598 2015-01-31 21:00:00  1017  2015-01-31
# 86690 2015-01-31 22:00:00   836  2015-01-31
# 86874 2015-01-31 23:00:00   558  2015-01-31
#
# [740 rows x 5 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(filter_zip_daily_df.pivot_table('cnt', index='date', columns='zip_code'),
           lw=.5, cmap='GnBu');

# %% [markdown]
# ### 시간대별 zip_code의 추이

# %%
filter_zip_df['hour'] = filter_zip_df['pickup_hour'].dt.hour

# %%
filter_zip_df.head(3)
# Out:
#    zip_code                                      zip_code_geom pickup_hour  \
# 0     10028  POLYGON((-73.96316 40.777772, -73.96323 40.777...  2015-01-01
# 2     10069  POLYGON((-73.995969 40.774012, -73.996142 40.7...  2015-01-01
# 11    11215  POLYGON((-74.000995 40.654067, -74.002144 40.6...  2015-01-01
#
#     cnt        date  hour
# 0   120  2015-01-01     0
# 2     8  2015-01-01     0
# 11   20  2015-01-01     0

# %%
plt.figure(figsize=(15,8))
sns.heatmap(filter_zip_df.pivot_table('cnt', index='hour', columns='zip_code', aggfunc='mean'),
           lw=.5, cmap='GnBu');
